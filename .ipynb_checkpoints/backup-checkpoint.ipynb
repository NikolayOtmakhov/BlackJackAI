# %%
import deck
import player
import pandas as pd

# create deck and player
d = deck.Deck()
pl = player.Player()


class mem:
    count = 0
    aces = 0
    used_aces = 0
    value = 0
    result = 0
    save_value = 0
    cards = 0
    value_without_ace_red = 0

def give_player_card_and_count():
    card = d.take_card()
    value = card.value
    mem.value = pl.card_value_total()
    mem.value_without_ace_red += value
    mem.cards += 1
    if value > 9:
        mem.count -= 1
    if value < 7:
        mem.count += 1
    if value == 11:
        mem.aces += 1
    pl.give_card(card)

df = pd.DataFrame(columns = ["Count", "Aces", "Aces_Used", "Cards", "Value" , "Result"] )
# df = pd.read_csv("file1.csv", index_col=0)

data_entries = 0
needed_rows = 50000
while data_entries < needed_rows:
    give_player_card_and_count()
    give_player_card_and_count()
    while mem.value < 22:
        mem.used_aces = \
        (mem.value_without_ace_red - mem.value)/10        
        if data_entries % 100 == 0:
            print("{:12.2f}% Complete".format(data_entries/needed_rows*100))
        if data_entries % 50000 == 0:
            df.to_csv("file1.csv")
            print(f"DF ROWS SAVED: {df.shape[0]}")
        mem.result = 0
        mem.save_value = mem.value
        give_player_card_and_count()
        if mem.value < 22 and mem.value >= mem.save_value:
            mem.result = 1
#         print(f"{mem.value} {mem.save_value}")
        if mem.value < 22 and mem.value < mem.save_value:
            result_temp = 0.5
            if mem.save_value == 21:
                result_temp = 0
            elif mem.save_value < 13:
                result_temp = 1
            else:
                result_temp = 0.2
                if mem.used_aces < mem.aces:
                    result_temp = 0.4
            mem.result = result_temp
        df.loc[len(df)] =([mem.count, mem.aces, mem.used_aces, mem.cards, mem.save_value , mem.result])
        data_entries += 1
        if d.cards_left() < 20:
            d = deck.Deck()
            mem.count = 0
    mem.value = 0
    mem.aces = 0
    mem.result = 0
    mem.cards = 0
    mem.value_without_ace_red = 0
    pl.init_or_reset_hand()
# Out:
#         0.00% Complete
# DF ROWS SAVED: df.shape[0]
#         0.20% Complete
#         0.40% Complete
#         0.60% Complete
#         0.80% Complete
#         1.00% Complete
#         1.20% Complete
#         1.40% Complete
#         1.60% Complete
#         1.80% Complete
#         2.00% Complete
#         2.20% Complete
#         2.40% Complete
#         2.60% Complete
#         2.80% Complete
#         3.00% Complete
#         3.20% Complete
#         3.40% Complete
#         3.60% Complete
#         3.80% Complete
#         4.00% Complete
#         4.20% Complete
#         4.40% Complete
#         4.60% Complete
#         4.80% Complete
#         5.00% Complete
#         5.20% Complete
#         5.40% Complete
#         5.60% Complete
#         5.80% Complete
#         6.00% Complete
#         6.20% Complete
#         6.40% Complete
#         6.60% Complete
#         6.80% Complete
#         7.00% Complete
#         7.20% Complete
#         7.40% Complete
#         7.60% Complete
#         7.80% Complete
#         8.00% Complete
#         8.20% Complete
#         8.40% Complete
#         8.60% Complete
#         8.80% Complete
#         9.00% Complete
#         9.20% Complete
#         9.40% Complete
#         9.60% Complete
#         9.80% Complete
#        10.00% Complete
#        10.20% Complete
#        10.40% Complete
#        39.80% Complete
#        40.00% Complete
#        40.20% Complete
#        40.40% Complete
#        40.60% Complete
#        40.80% Complete
#        41.00% Complete
#        41.20% Complete
#        41.40% Complete
#        41.60% Complete
#        41.80% Complete
#        42.00% Complete
#        42.20% Complete
#        42.40% Complete
#        42.60% Complete
#        42.80% Complete
#        43.00% Complete
#        43.20% Complete
#        43.40% Complete
#        43.60% Complete
#        43.80% Complete
#        44.00% Complete
#        44.20% Complete
#        44.40% Complete
#        44.60% Complete
#        44.80% Complete
#        45.00% Complete
#        45.20% Complete
#        45.40% Complete
#        45.60% Complete
#        45.80% Complete
#        46.00% Complete
#        46.20% Complete
#        46.40% Complete
#        46.60% Complete
#        46.80% Complete
#        47.00% Complete
#        47.20% Complete
#        47.40% Complete
#        47.60% Complete

# %%
df.to_csv("file1.csv")

# %%
df = pd.read_csv("file1.csv", index_col=0)

# %%
df.shape[0]
# Out:
# 350000

# %%
import tensorflow as tf
import keras
from keras import layers
from keras.layers.experimental import preprocessing
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split


df = pd.read_csv("file1.csv", index_col=0)
df = sklearn.utils.shuffle(df)
df_features = df
df_label = df_features.pop("Result")

df_features = np.array(df_features)

X_train, X_test, y_train, y_test = train_test_split(
    df_features, df_label, test_size=0.33)

normalize = preprocessing.Normalization()
normalize.adapt(df_features)

blackjack_model = tf.keras.Sequential([
    normalize,
    layers.Dense(64, activation='relu'),
#     keras.layers.Dropout(0.1),
    layers.Dense(64),
    layers.Dense(1)
])

blackjack_model.compile(loss = tf.losses.MeanSquaredError(),
                      optimizer = tf.optimizers.Adam())

blackjack_model.fit(X_train, y_train, epochs=10, 
    validation_data=(X_test, y_test))

blackjack_model.save('saved_model/blackjack_model')
# Out:
# Epoch 1/10
# 7329/7329 [==============================] - 11s 2ms/step - loss: 0.0940 - val_loss: 0.0903
# Epoch 2/10
# 7329/7329 [==============================] - 11s 2ms/step - loss: 0.0901 - val_loss: 0.0885
# Epoch 3/10
# 7329/7329 [==============================] - 11s 2ms/step - loss: 0.0896 - val_loss: 0.0879
# Epoch 4/10
# 7329/7329 [==============================] - 11s 2ms/step - loss: 0.0894 - val_loss: 0.0877
# Epoch 5/10
# 7329/7329 [==============================] - 11s 1ms/step - loss: 0.0892 - val_loss: 0.0875
# Epoch 6/10
# 7329/7329 [==============================] - 11s 2ms/step - loss: 0.0890 - val_loss: 0.0884
# Epoch 7/10
# 7329/7329 [==============================] - 11s 2ms/step - loss: 0.0890 - val_loss: 0.0874
# Epoch 8/10
# 7329/7329 [==============================] - 11s 2ms/step - loss: 0.0888 - val_loss: 0.0874
# Epoch 9/10
# 7329/7329 [==============================] - 11s 2ms/step - loss: 0.0888 - val_loss: 0.0869
# Epoch 10/10
# 7329/7329 [==============================] - 11s 2ms/step - loss: 0.0887 - val_loss: 0.0875
# WARNING:tensorflow:From /home/nikolaymwd/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/nikolaymwd/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: saved_model/blackjack_model/assets
